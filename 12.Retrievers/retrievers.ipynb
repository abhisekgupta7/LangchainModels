# %%
# %pip install langchain chromadb faiss-cpu tiktoken pypdf langchain_openai langchain_community_retrievers wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement langchain_community_retrievers (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for langchain_community_retrievers

# %%
from langchain_community_retrievers import WikipediaRetriever
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from langchain_community_retrievers import WikipediaRetriever
#
# ModuleNotFoundError: No module named 'langchain_community_retrievers'

# %%
retreiver = WikipediaRetriever(
    top_k_results=2,
    lang="en"
)

# %%
query = "What is Langchain?"

docs=retreiver.invoke(query)

# %%
for i,doc in enumerate(docs):
    print(f"Document {i+1}:")
    print(f"Title: {doc.metadata['title']}")
    print(f"URL: {doc.metadata['url']}")
    print(f"Content: {doc.page_content[:500]}...")  # Print the first 500 characters of the content
    print("\n")
